-- %%
%sql
CREATE TABLE IF NOT EXISTS default.processed_org
USING csv
OPTIONS (
  path "/mnt/processed",
  header "true",
  inferSchema "true"
);

-- %%
%sql
CREATE OR REPLACE VIEW default.view_processed_org AS
SELECT * FROM default.processed_org;
